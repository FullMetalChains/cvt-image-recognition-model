# %%
# !pip install -q mediapipe
# !wget -q https://storage.googleapis.com/mediapipe-models/hand_landmarker/hand_landmarker/float16/1/hand_landmarker.task
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 43.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 14.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-api-core 1.34.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<4.0.0dev,>=3.19.5, but you have protobuf 4.25.6 which is incompatible.
# google-cloud-bigtable 2.27.0 requires google-api-core[grpc]<3.0.0dev,>=2.16.0, but you have google-api-core 1.34.1 which is incompatible.
# pandas-gbq 0.25.0 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# tensorflow-decision-forests 1.10.0 requires tensorflow==2.17.0, but you have tensorflow 2.17.1 which is incompatible.

# %%
import os
import cv2
import mediapipe as mp
from mediapipe import solutions
from mediapipe.framework.formats import landmark_pb2
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
import numpy as np

# %%
# Constants
MARGIN = 10  # pixels
FONT_SIZE = 1
FONT_THICKNESS = 1
HANDEDNESS_TEXT_COLOR = (88, 205, 54)  # vibrant green
INPUT_FOLDER = "/kaggle/input/isl-words-dataset-reduced-sharpened/isl_words_dataset_reduced_sharpened"
OUTPUT_FOLDER = "/kaggle/working/isl_words_landmarks"

# %%
# Ensure output directory exists
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# %%
def draw_landmarks_on_image(rgb_image, detection_result):
    hand_landmarks_list = detection_result.hand_landmarks
    handedness_list = detection_result.handedness
    annotated_image = np.copy(rgb_image)

    for idx in range(len(hand_landmarks_list)):
        hand_landmarks = hand_landmarks_list[idx]
        handedness = handedness_list[idx]

        hand_landmarks_proto = landmark_pb2.NormalizedLandmarkList()
        hand_landmarks_proto.landmark.extend([
            landmark_pb2.NormalizedLandmark(x=landmark.x, y=landmark.y, z=landmark.z) for landmark in hand_landmarks
        ])
        solutions.drawing_utils.draw_landmarks(
            annotated_image,
            hand_landmarks_proto,
            solutions.hands.HAND_CONNECTIONS,
            solutions.drawing_styles.get_default_hand_landmarks_style(),
            solutions.drawing_styles.get_default_hand_connections_style())

        height, width, _ = annotated_image.shape
        x_coordinates = [landmark.x for landmark in hand_landmarks]
        y_coordinates = [landmark.y for landmark in hand_landmarks]
        text_x = int(min(x_coordinates) * width)
        text_y = int(min(y_coordinates) * height) - MARGIN

        cv2.putText(annotated_image, f"{handedness[0].category_name}",
                    (text_x, text_y), cv2.FONT_HERSHEY_DUPLEX,
                    FONT_SIZE, HANDEDNESS_TEXT_COLOR, FONT_THICKNESS, cv2.LINE_AA)

    return annotated_image

# %%
# Initialize the hand detector
base_options = python.BaseOptions(model_asset_path='hand_landmarker.task')
options = vision.HandLandmarkerOptions(base_options=base_options, num_hands=2)
detector = vision.HandLandmarker.create_from_options(options)

# %%
def process_images(input_folder, output_folder):
    for root, _, files in os.walk(input_folder):
        for file in files:
            if file.lower().endswith((".jpg", ".png", ".jpeg")):
                input_path = os.path.join(root, file)
                rel_path = os.path.relpath(input_path, input_folder)
                output_path = os.path.join(output_folder, rel_path)
                os.makedirs(os.path.dirname(output_path), exist_ok=True)

                image = mp.Image.create_from_file(input_path)
                detection_result = detector.detect(image)

                annotated_image = draw_landmarks_on_image(image.numpy_view(), detection_result)

                cv2.imwrite(output_path, cv2.cvtColor(annotated_image, cv2.COLOR_RGB2BGR))
                print(f"Processed and saved: {output_path}")

# %%
# Process all images in the dataset
process_images(INPUT_FOLDER, OUTPUT_FOLDER)
# Out:
# Processed and saved: /kaggle/working/isl_words_landmarks/small/623.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/208.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/187.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/682.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/489.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/824.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/768.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/82.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/334.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/829.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/630.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/120.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/512.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/604.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/480.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/123.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/872.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/477.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/167.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/452.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/701.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/9.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/241.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/529.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/414.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/494.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/401.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/455.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/634.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/329.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/603.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/854.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/296.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/784.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/339.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/155.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/734.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/148.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/31.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/847.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/552.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/376.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/669.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/337.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/223.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/347.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/354.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/571.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/681.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/618.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/318.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/676.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/488.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/394.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/884.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/848.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/459.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/557.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/749.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/181.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/411.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/370.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/862.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/297.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/556.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/437.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/201.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/14.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/860.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/316.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/898.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/797.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/679.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/714.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/483.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/205.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/810.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/213.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/25.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/small/728.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/785.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/239.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/58.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/6.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/760.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/243.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/265.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/289.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/361.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/82.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/295.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/668.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/334.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/463.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/211.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/818.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/178.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/759.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/601.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/375.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/620.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/872.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/559.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/372.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/241.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/529.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/403.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/393.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/494.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/401.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/525.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/44.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/719.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/302.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/159.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/677.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/807.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/498.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/565.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/332.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/310.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/169.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/421.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/104.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/344.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/841.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/650.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/350.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/609.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/624.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/318.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/321.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/675.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/696.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/602.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/224.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/616.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/893.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/293.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/686.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/305.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/181.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/842.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/596.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/533.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/661.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/855.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/128.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/36.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/144.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/437.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/812.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/471.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/508.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/547.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/428.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/116.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/203.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/875.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/stand/810.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/which/521.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/which/270.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/which/185.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/which/622.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/which/577.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/which/486.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/which/766.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/which/67.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/which/768.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/which/361.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/which/788.jpg
# Processed and saved: /kaggle/working/isl_words_landmarks/which